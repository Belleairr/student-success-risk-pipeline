# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_rows',4500)
pd.set_option('display.max_columns',40)

# %%
#from google.colab import files
#uciFile = files.upload()

df = pd.read_csv('../data/processed/cleaned_student_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 #from google.colab import files
#       2 #uciFile = files.upload()
#       3
# ----> 4 df = pd.read_csv('../data/processed/cleaned_student_data.csv')
#
# ...

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
df= df.rename(columns={'Daytime/evening attendance\t':'Daytime/evening attendance','Unemployment rate':'Unemployment rate %','Inflation rate':'Inflation rate %'})
