# %%
#Our Exploratory Data Analysis Notebook

#This notebook explores the "Predict Students Dropout and Academic Success" dataset.

#Our goals are to:
# - Understand the dataset structure
# - Identify data quality issues
# - Explore feature distributions
# - Analyze patterns related to student dropout
# Out:
# Running cells with 'Python 3.14.0' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
# Out:
# Running cells with 'Python 3.14.0' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
#load dataset from raw data directory

df = pd.read_csv('data/raw/uci_success_dropout_data.csv')

# %%
#view data loaded for first 10 entries
df.head(10)
